# %% [markdown]
# <a href="https://colab.research.google.com/github/UNB-TME/Assignment-2/blob/main/Using_Kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
path_name = "/content/drive/MyDrive/Teaching/TME_6015/week_6/emotions.zip"
df = pd.read_csv(path_name, compression='zip')

# %%
import zipfile
import os

# Path to the zip file
zip_path = "/content/drive/MyDrive/Teaching/TME_6015/week_6/tumours.zip"

# Path where you want to extract the zip file
extract_path = "/content/drive/MyDrive/Teaching/TME_6015/week_6/tumours_dataset"

# Create the extract folder if it doesn't exist
os.makedirs(extract_path, exist_ok=True)

# Create a ZipFile Object
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # Extract all the contents of zip file in the extract folder
    zip_ref.extractall(extract_path)

# %%
import tensorflow as tf
import tensorflow_hub as hub

m = tf.keras.Sequential([
    hub.KerasLayer("https://www.kaggle.com/models/google/mobilenet-v2/frameworks/TensorFlow2/variations/035-128-classification/versions/2")
])
m.build([None, 128, 128, 3])
